# %%
def Calculator (a, b, op):
    if op == '+':
        return a+b
    elif op == '-':
        return a-b
    elif op == '*':
        return a*b
    elif op == '/':
        return a/b
    else:
        return None
a, op, b = input().split()
a = int(a)
b = int(b)
print(f"{a} {op} {b} = {Calculator(a, b, op)}")
# Out:
# 8 + 9 = 17

# %% [markdown]
# W5A1: Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( a, b) ->
# int:

# %%
def Max_Of_Two(a: int, b: int) -> int:
    if a > b:
        return a
    else:
        return b

assert Max_Of_Two(-12, 0) == 0
assert Max_Of_Two(1, 2) == 2
assert Max_Of_Two(3, 3) == 3
assert Max_Of_Two(-5, -10) == -5
assert Max_Of_Two(100, 50) == 100
print("All test cases passed!")
# Out:
# All test cases passed!

# %% [markdown]
# W5A2: Viết hàm hoán đổi hai số nguyên. def swap(a, b) -> Tuple[int, int]:

# %%
def swap(a: int, b: int) -> Tuple[int, int]:
    return b, a
assert swap(1, 2) == (2, 1)
assert swap(-1, 0) == (0, -1)
assert swap(5, 5) == (5, 5)
assert swap(-3, -7) == (-7, -3)
assert swap(100, 50) == (50, 100)
print("All test cases passed!")
# Out:
# All test cases passed!

# %% [markdown]
# W5A3: Viết hàm kiểm tra một số có phải là số nguyên tố hay không?

# %%
def is_prime(n: int) -> bool:
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False     
    return True
print(is_prime(17))  
print(is_prime(10)) 
print(is_prime(2))
print(is_prime(5))
print(is_prime(45))
# Out:
# True
# False
# True
# True
# False

# %% [markdown]
# W5A4: VIết hàm kiểm tra một số có phải số hoàn hảo hay không, xử lý trên dữ liệu kiểu số nguyên.

# %% [markdown]
# Số hoàn hảo (Perfect Number) là số nguyên dương mà tổng của tất cả các ước số thực sự của nó (không bao gồm chính nó) bằng chính số đó.

# %%
def is_perfect_number(n: int) -> bool:
    if n <= 1:
        return False
    total_sum = 1
    for i in range(2, int(n**0.5)+ 1):
        if n % i == 0:
            if i * i != n:
                total_sum += i + (n // i)
            else:
                total_sum += i     
    return total_sum == n
numbers = [6, 28, 496, 8128, 10]
for num in numbers:
    print(f"Số {num} có phải số hoàn hảo? {is_perfect_number(num)}")
# Out:
# Số 6 có phải số hoàn hảo? True
# Số 28 có phải số hoàn hảo? True
# Số 496 có phải số hoàn hảo? True
# Số 8128 có phải số hoàn hảo? True
# Số 10 có phải số hoàn hảo? False

# %% [markdown]
# W5A5: Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của phần tử
# đầu tiên có giá trị k trong list số nguyên, nếu không có thì trả về -1

# %%
def find_first_index(lst: List[int], k: int) -> int:
    for i in range(len(lst)):
        if lst[i] == k:
            return i
    return -1
print(find_first_index([1, 2, 3, 4, 5], 3))
print(find_first_index([10, 12, 14, 16, 18], 15))
print(find_first_index([5, 5, 5, 5, 5], 5))
print(find_first_index([5, 10, 15, 20, 25], 10))
print(find_first_index([100, 200, 300, 400, 500], 350))
# Out:
# 2
# -1
# 0
# 1
# -1

# %% [markdown]
# W5A6: Viết hàm tính giai thừa. Nhập vào số nguyên n, trả về giai thừa của n (n!)

# %%
def tinh_giai_thua(n: int) -> int:
    if n < 0:
        return None 
    ket_qua = 1
    for i in range(2, n + 1):
        ket_qua *= i
    return ket_qua

# %% [markdown]
# W5A8: Khoảng cách Hamming giữa hai số nguyên là số lượng vị trí khác nhau giữa hai dãy bits tương ứng
# của chúng. Ví dụ: Khoảng cách Hamming giữa 1 (1) và 4 (100) là 2.
# Cho hai số nguyên x và y, hãy viết hàm trả về khoảng cách Hamming giữa hai số này.
# Khoảng cách Hamming là cái tên được đặt theo tên của Richard Hamming, người giới thiệu lý
# thuyết này trong tài liệu có tính cơ sở của ông về mã phát hiện lỗi và sửa lỗi (error-detecting and
# error-correcting codes). Nó được sử dụng trong kỹ thuật viễn thông để tính số lượng các bit trong
# một từ nhị phân (binary word) bị đổi ngược, như một hình thức để ước tính số lỗi xảy ra trong quá
# trình truyền thông, và vì thế, đôi khi, nó còn được gọi là khoảng cách tín hiệu (signal distance). Việc
# phân tích trọng số Hamming của các bit còn được sử dụng trong một số ngành, bao gồm lý thuyết
# tin học, lý thuyết mã hóa, và mật mã học. Tuy vậy, khi so sánh các dãy ký tự có chiều dài khác
# nhau, hay các dãy ký tự có xu hướng không chỉ bị thay thế không thôi, mà còn bị ảnh hưởng bởi dữ
# liệu bị lồng thêm vào, hoặc bị xóa đi, phương pháp đo lường phức tạp hơn, như khoảng cách
# Levenshtein (Levenshtein distance) là một phương pháp có tác dụng và thích hợp hơn.

# %% [markdown]
# ****Hệ 10 -> Hệ 2(Nhị phân)
# Chuyển 1 số từ hệ thập phân sang hệ nhị phân (chia liên tiếp cho 2 lấy phần dư -> làm ngược)

# %%
def ten_to_bin(n: int) -> str:
    ans = " "
    while n>0:
        ans = str(n%2) + ans
        n//=2
    return ans
print(ten_to_bin(10))
print(ten_to_bin(5))
print(ten_to_bin(54))
print(ten_to_bin(0))
print(ten_to_bin(11))
def hamming(n: int, m: int) -> int:
    n_bin = ten_to_bin(n)
    m_bin = ten_to_bin(m)
    if len(n_bin) < len(m_bin):
        n_bin = "0" + n_bin
    elif len(n_bin) > len(m_bin):
        m_bin = "0" + m_bin
    count = 0
    for i in range(len(n_bin)):
        if n_bin[i] != m_bin[i]:
            count += 1
    return count
print(hamming(10, 5))
print(hamming(4, 11))
print(hamming(3, 4))
print(hamming(54, 75))
print(hamming(27, 30))
# Out:
# 1010
# 101
# 110110
#
# 1011
# 4
# 4
# 3
# 6
# 2

# %% [markdown]
# W5A9: Viết hàm trả về tổng các chữ số của số nguyên dương n

# %%
def sum_of_digits(n: int) -> int:
    total = 0
    while n > 0:
       k = n % 10
       total += k
       n//=10
    return total
print(sum_of_digits(123))
print(sum_of_digits(3633))
print(sum_of_digits(100))
print(sum_of_digits(342))
print(sum_of_digits(764))
# Out:
# 6
# 15
# 1
# 9
# 17

# %% [markdown]
# W5A10: Hai từ được gọi là đẳng cấu nếu các kí tự trong một từ có thể được ánh xạ để được từ còn lại. Ánh
# xạ một kí tự nghĩa là thay đổi toàn bộ các kí tự đó trong từ bởi một kí tự khác. Thứ tự của các kí tự
# được giữ không đổi. Hai kí tự khác nhau không thể ánh xạ đến cùng một kí tự, nhưng một kí tự có
# thể ánh xạ thành chính nó. Ví dụ, từ "abca" và "zbxz" là hai từ đẳng cấu vì ta có thể ánh xạ 'a' thành
# 'z', 'b' thành 'b' và 'c' thành 'x'.
# Viết hàm trả về \(true\) nếu hai từ \(a\) và \(b\) là đẳng cấu, ngược lại \(false\). Bạn có thể giả sử hai
# từ đầu vào có cùng độ dài.

# %%
def is_isomorphic(a, b):
    map_a = [-1] * 256
    map_b = [-1] * 256
    for i in range(len(a)):
        char_a = ord(a[i])
        char_b = ord(b[i])
        if map_a[char_a] != map_b[char_b]:
            return False
        map_a[char_a] = i
        map_b[char_b] = i
    return True
print(is_isomorphic("egg", "add"))
print(is_isomorphic("far", "bar"))
print(is_isomorphic("turtle", "purple"))
print(is_isomorphic("Letters", "Numbers"))
print(is_isomorphic("abc", "efg"))
# Out:
# True
# True
# True
# False
# True

# %% [markdown]
# W5A11: Viết hàm is_product_divisible_by_10(a, b) trả về True nếu tích a*b chia hết cho 10, ngược lại False.

# %%
def is_product_divisible_by_10(a, b):
    return (a * b) % 10 == 0
print(is_product_divisible_by_10(2, 5))
print(is_product_divisible_by_10(3, 4))
print(is_product_divisible_by_10(10, 20))
print(is_product_divisible_by_10(7, 8))
print(is_product_divisible_by_10(0, 5))
# Out:
# True
# False
# True
# False
# True

# %% [markdown]
# W5A12: Viết hàm divide_with_remainder(dividend, divisor) trả về bộ (q, r) sao cho dividend = divisor*q + r và
# 0 <= |r| < |divisor|.

# %%
def divide_with_remainder(dividend, divisor):
    q = int(dividend / divisor)
    r = dividend - (divisor * q)
    return (q, r)
assert divide_with_remainder(10, 3) == (3, 1)
assert divide_with_remainder(20, 4) == (5, 0)
assert divide_with_remainder(15 ,4) == (3, 3)
assert divide_with_remainder(7, 2) == (3, 1)
assert divide_with_remainder(9, 4) == (2, 1)
print("All test cases passed!")
# Out:
# All test cases passed!

# %% [markdown]
# W5A13:  Viết hàm max_of_two(a, b) trả về số lớn hơn trong hai số

# %%
def max(a, b):
    if a > b:
        return a
    elif a < b:
        return b
assert max(5, 10) == 10
assert max(-1, -5) == -1
assert max(3, 2) == 3
assert max(-5, -10) == -5
assert max(100, 50) == 100
print("All test cases passed!")
# Out:
# All test cases passed!

# %% [markdown]
# W5A14: Viết hàm compute(a, b, op) thực hiện phép tính a (+|-|*|/) b tùy theo ký tự op.

# %% [markdown]
# W5A7: Viết hàm giả lập một máy tính bỏ túi.
# Hàm thực hiện tính toán kết quả của phép toán giữa số \( num1 \) và \( num2 \) với toán tử \( operat
# \)
# Biết các toán tử đơn giản thực hiện phép toán lần lượt là:
# Phép trừ \( - \)
# Phép cộng \( + \)
# Phép chia \( / \)
# Phép nhân \( * \)
# Kết quả làm tròn đến chữ số thập phân thứ hai.
# Đầu vào: Hai số thực và phép toán cần thực hiện (trong số các phép toán \(+, -, *, /\)).
# Đầu ra: Kết quả phép toán.

# %% [markdown]
# W5A15: Viết hàm is_right_triangle(a, b, c) trả về True nếu ba số có thể là ba cạnh của tam giác vuông

# %%
def is_right_triangle(a, b, c):
    if (a + b <= c) or (a + c <= b) or (b + c <= a):
        return False
    return (a**2 + b**2 == c**2) or (a**2 + c**2 == b**2) or (b**2 + c**2 == a**2)
assert is_right_triangle(3, 4, 5) == True
assert is_right_triangle(1, 2, 3) == False
assert is_right_triangle(5, 12, 13) == True
assert is_right_triangle(7, 24, 25) == True
assert is_right_triangle(1, 1, 1) == False
print("All test cases passed!")
# Out:
# All test cases passed!
