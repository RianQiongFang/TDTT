# %% [markdown]
# #Python built-in functions

# %% [markdown]
# Python built-in functions are defined by the Python language and ready to use

# %%
max_value = max(5, 4)
print("The larger number is: ", max_value)
# Out:
# The larger number is:  5

# %% [markdown]
# #Defining new functions

# %% [markdown]
# A function definition specifies the name of a new function and the sequence of statements that run when the function is called. Here's an example:

# %%
def inches_to_feet(inches):
  return inches/12

# %% [markdown]
# Now that we've defined a function, we can call it the same way we call built-in functions.

# %%
p = inches_to_feet(65)
print(p)
# Out:
# 5.416666666666667

# %% [markdown]
# #Stack call

# %% [markdown]
# When a function is called, Python uses call stack to keep track of where it is in the program.

# %%
def func_c():
    print("Inside C")

def func_b():
    print("Inside B")
    func_c()
    print("Back in B")

def func_a():
    print("Inside A")
    func_b()
    print("Back in A")

func_a()
# Out:
# Inside A
# Inside B
# Inside C
# Back in B
# Back in A

# %% [markdown]
# 1. start func_a-->  stack: func_a
# 2. inside func_a() calls func_b() --> stack: func_b -> func_a
# 3. inside func_b() calls func_c() --> stack: func_c -> func_b -> func_a
# 4. func_c() finishes, back to func_b() --> stack: func_b -> func_a
# 5. func_b() finishes, back to func_a() --> stack: func_a
# 6. func_a() finish --> stack: (empty)

# %% [markdown]
# #Local vs. global variables

# %%
counter = 0

def show_counter():
    local_counter = 1
    print("Current counter:", counter)


def increment():
    global counter
    counter = counter + 1
    print("Good_increment:", counter)

increment()
show_counter()
# Out:
# Good_increment: 1
# Current counter: 1

# %% [markdown]
# #Program testing

# %%
def add(a, b):
    """
    Returns the sum of two numbers.

    Parameters:
        a (int or float): The first number.
        b (int or float): The second number.

    Returns:
        int or float: The sum of a and b.
    """
    return a - b

# %%
def test_integers():
    assert add(2, 3) == 5, "Expected 2 + 3 to be 5"
    assert add(-1, 1) == 0, "Expected -1 + 1 to be 0"

def test_floats():
    assert add(2.5, 3.5) == 6.0, "Expected 2.5 + 3.5 to be 6.0"

def test_mixed():
    assert add(2, 3.5) == 5.5, "Expected 2 + 3.5 to be 5.5"

if __name__ == "__main__":
    test_integers()
    test_floats()
    test_mixed()
    print("All tests passed!")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_1206/763481719.py in <cell line: 0>()
#      10
#      11 if __name__ == "__main__":
# ---> 12     test_integers()
#      13     test_floats()
#      14     test_mixed()
#
# /tmp/ipykernel_1206/763481719.py in test_integers()
#       1 def test_integers():
# ----> 2     assert add(2, 3) == 5, "Expected 2 + 3 to be 5"
#       3     assert add(-1, 1) == 0, "Expected -1 + 1 to be 0"
#       4
#       5 def test_floats():
#
# AssertionError: Expected 2 + 3 to be 5

# %% [markdown]
# Use assert to check the expected output of a function against the actual result.
#
# If the condition is True, the program continues normally (test passes).
#
# If the condition is False, Python raises an AssertionError with an optional message, indicating which test failed.
#
# In this example, the add function contains an error: instead of adding two numbers, it subtracts them, causing an AssertionError. Change the - operator in the return statement to + to make all the tests pass.

# %% [markdown]
# #Exercise

# %% [markdown]
# #Ex1: Fibonacci number

# %% [markdown]
# Write a function fib(n) that return nth Fibonacci number, where:
#
# fib(0) = 0
#
# fib(1) = 1
#
# fib(2) = fib(1) + fib(0) = 1
#
# fib(3) = fib(2) + fib(1) = 2
#
# fib(n) = fib(n-1) + fib(n-2)

# %%
def fib(n):
    """
    Returns the n-th Fibonacci number.

    Parameters:
        n (int): The position in the Fibonacci sequence.

    Returns:
        int: The n-th Fibonacci number.
    """
    return 0

# %%
def test_first_two():
    assert fib(0) == 0, "fib(0) should be 0"
    assert fib(1) == 1, "fib(1) should be 1"

def test_small_numbers():
    assert fib(2) == 1, "fib(2) should be 1"
    assert fib(3) == 2, "fib(3) should be 2"
    assert fib(4) == 3, "fib(4) should be 3"

def test_large_number():
    assert fib(10) == 55, "fib(10) should be 55"


if __name__ == "__main__":
  test_first_two()
  test_small_numbers()
  test_large_number()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_1206/3071201784.py in <cell line: 0>()
#      13
#      14 if __name__ == "__main__":
# ---> 15   test_first_two()
#      16   test_small_numbers()
#      17   test_large_number()
#
# /tmp/ipykernel_1206/3071201784.py in test_first_two()
#       1 def test_first_two():
#       2     assert fib(0) == 0, "fib(0) should be 0"
# ----> 3     assert fib(1) == 1, "fib(1) should be 1"
#       4
#       5 def test_small_numbers():
#
# AssertionError: fib(1) should be 1

# %% [markdown]
# #Ex2: factorial

# %% [markdown]
# Write a function that returns factorial of n
# your task:
# 1. write clear docstring/specification
# 2. create test cases
# 3. implement the function correctly

# %% [markdown]
# # Ex3: Prime number
# Write a function that that determines whether a given number is prime. Return True if the number is prime; otherwise, return False.
#
# your task:
# 1. write clear docstring/specification
# 2. create test cases
# 3. implement the function correctly
